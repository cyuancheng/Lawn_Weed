# %% [markdown]
# <a href="https://colab.research.google.com/github/cyuancheng/Lawn_Weed/blob/master/01_Weed_imaging_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Creating weed imaging classifier with fastai
#
# - Chiyuan Cheng
# - March 2019

# %% [markdown]
# ## Objective
# The objective is to create a Deep Learning Web App to classify lawn weeds  into 7 most common weeds.

# %%
from fastai.vision import *
from fastai.widgets import *

# %% [markdown]
# mount Google Drive locally

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Get image files from Google Image
#
# The images of 10 most common weeds have previoulsy downloaded from google image, and store on the google drive

# %%
path = Path('gdrive/My Drive/fastai_data')

# %%
path.ls()
# Out:
# [PosixPath('gdrive/My Drive/fastai_data/dandelion.txt'),
#  PosixPath('gdrive/My Drive/fastai_data/dandelion'),
#  PosixPath('gdrive/My Drive/fastai_data/crabgrass.txt'),
#  PosixPath('gdrive/My Drive/fastai_data/crabgrass'),
#  PosixPath('gdrive/My Drive/fastai_data/whiteclover.txt'),
#  PosixPath('gdrive/My Drive/fastai_data/whiteclover'),
#  PosixPath('gdrive/My Drive/fastai_data/dollarweed.txt'),
#  PosixPath('gdrive/My Drive/fastai_data/dollarweed'),
#  PosixPath('gdrive/My Drive/fastai_data/creepingcharlie.txt'),
#  PosixPath('gdrive/My Drive/fastai_data/creepingcharlie'),
#  PosixPath('gdrive/My Drive/fastai_data/oxalis'),
#  PosixPath('gdrive/My Drive/fastai_data/annualbluegrass.txt'),
#  PosixPath('gdrive/My Drive/fastai_data/annualbluegrass'),
#  PosixPath('gdrive/My Drive/fastai_data/oxalis.txt'),
#  PosixPath('gdrive/My Drive/fastai_data/models'),
#  PosixPath('gdrive/My Drive/fastai_data/export.pkl')]

# %%
# !bash -c 'ls'
# Out:
# gdrive	sample_data

# %% [markdown]
# 10 weeds

# %%
classes = ['dandelion','crabgrass','whiteclover', 'dollarweed', 'creepingcharlie', 'oxalis', 'annualbluegrass']

# %% [markdown]
# view data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# download images locally and clean the image using ImageCleaner

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['annualbluegrass',
#  'crabgrass',
#  'creepingcharlie',
#  'dandelion',
#  'dollarweed',
#  'oxalis',
#  'whiteclover']

# %%
data.show_batch(rows=3, figsize=(8,8))

# %%
data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (7, 1830, 457)

# %% [markdown]
# ## Data augmentation
# try data augmentation

# %%
bs = 64

# %%
tfms = get_transforms(max_rotate=30, max_zoom=1.5, max_lighting=0.4, max_warp=0.4,
                      p_affine=1., p_lighting=1.)

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), padding_mode='reflection', size=224, bs=bs, num_workers=4).normalize(imagenet_stats)

# %%
def _plot(i,j,ax):
    x,y = data.train_ds[3]
    x.show(ax, y=y)

plot_multi(_plot, 3, 3, figsize=(8,8))

# %% [markdown]
# ## Train model
#
# We start with resnet50 for our model, and will train for 10 epochs.

# %%
learn = cnn_learner(data, models.resnet50, metrics=accuracy, bn_final=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 102502400it [00:04, 24980895.13it/s]

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.565680</td>
#       <td>0.855542</td>
#       <td>0.735230</td>
#       <td>02:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.340125</td>
#       <td>0.718100</td>
#       <td>0.829322</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.195587</td>
#       <td>0.716716</td>
#       <td>0.844639</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.072874</td>
#       <td>0.685522</td>
#       <td>0.877462</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.964514</td>
#       <td>0.619689</td>
#       <td>0.901532</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %% [markdown]
# Amazingly, we get accuracy of 90%! This is somewhat surprising because we mixed up different metric domains. We generally find with other algorithms that each time series behaves differently.

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(8,8), dpi=60)

# %%
interp.plot_top_losses(9, figsize=(10,10))

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates
#
# ince our model is working as we expect it to, we will unfreeze our model and train some more.

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(5, max_lr=slice(5e-5,5e-4))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/5 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(10,10))

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:01<00:00]
#     </div>
# Computing similarities...
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
# ...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# 'No images to show :)'

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
data.classes
# Out:
# ['annualbluegrass',
#  'crabgrass',
#  'creepingcharlie',
#  'dandelion',
#  'dollarweed',
#  'oxalis',
#  'whiteclover']

# %%
img = open_image(path/'oxalis'/'00000025.jpg')
img
# Out:
# Image (3, 333, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
classes = data.classes#['black', 'grizzly', 'teddys']
#data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)
data2 = ImageDataBunch.single_from_classes(path, classes, size=224).normalize(imagenet_stats)

learn = cnn_learner(data2, models.resnet34)
learn.load('stage-2')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-61-e1c4cee1d753> in <module>()
#       4
#       5 learn = cnn_learner(data2, models.resnet34)
# ----> 6 learn.load('stage-2')
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in load(self, file, device, strict, with_opt, purge, remove_module)
#     267             model_state = state['model']
#     268             if remove_module: model_state = remove_module_load(model_state)
# --> 269             get_model(self.model).load_state_dict(model_state, strict=strict)
#     270             if ifnone(with_opt,True):
#     271                 if not hasattr(self, 'opt'): self.create_opt(defaults.lr, self.wd)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     767         if len(error_msgs) > 0:
# ...

# %%
#learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category oxalis

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# ...
